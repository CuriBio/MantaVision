# %%
from mantavision import runTrackTemplate

# input_video_path:             Path to a directory of videos or single video to track an ROI.
#                               if input_video_path does not exist, is "" or "select" (case is ignored),
#                               a small window will pop up allowing selection from the file system.
#
# template_guide_image_path:    A guide image used to find a new template ROI in the video to track.
#                               if template_guide_image_path does not exist, is "" or "select (case is ignored),
#                               a small window will pop up allowing selection from the file system.
#                               if template_guide_image_path is "draw", a small window will pop up, and
#                               you can manually select a ROI from the first frame of the vido.
#
# guide_match_search_seconds:   How many seconds of each video to search for a ROI that best matches
#                               the template guide image. This new ROI from within the video
#                               will be used as a template to track throughout the entire video.
#                               Optional [default = entire video length].
#
# output_conversion_factor:     All output will be multiplied by this value. This can be used to convert 
#                               from microns to raw ADC values from the mantarray, so the SDK will produce
#                               correct force and displacement values since it expects ADC values.
#                               Optional [default = 1].
#
# microns_per_pixel:            Conversion factor from pixels to microns for results.
#                               Optional [default = 1].
#
# sub_pixel_search_increment:   Fraction of a pixel accuracy that matching will be performed to.
#                               Note that an initial +/- 1 pixel accuracy search is performed, and then
#                               a second refinement step with sub pixel accuracy is performed
#                               by searching a small region around the first match.
#                               Optional [default is None i.e. no sub pixel search]
#                               NOTE: This is not recommended for very hi resolution ZOOMED-IN videos.
#                                     If the template occupies most of the video frame (view),
#                                     the compute time can be significant e.g. compute time for a
#                                     template that is 4x larger will take 4*4 times longer.
#                                     But if the resolution of each pixel is close to the sub pixel step size,
#                                     the additional accuracy is almost certainly not worth the additional runtime.
#                                     i.e. for a 1 micron per pixel resolution and 0.5 micron sub pixel step,
#                                     the additional accuracy in results will be insignificant. 
#
# sub_pixel_refinement_radius   Number of pixels to search around the first match when performing
#                               a sub pixel accuracy refinement match
#                               Optional [default = 1]
#
# max_pixel_movement_per_frame  maximum movement in microns expected from one frame to the next.
#                               If specified, limits the search in each frame to an area around the previous
#                               match that is +/- max_movement_per_frame in x and y directions.
#                               Optional [default = None] which means the entire image is searched

config = {
    "input_video_path":             "../test_data/videos_to_track/to_track",
    "template_guide_image_path":    "draw",
    "guide_match_search_seconds":   5,
    "max_pixel_movement_per_frame": 200,
    # "output_conversion_factor":     309.9,
    # "microns_per_pixel":            4.64, # 0.93, #
    # "sub_pixel_search_increment":   0.4,
    # "sub_pixel_refinement_radius":  1,
}

runTrackTemplate(config)
# Out:
# Template Tracker running...
# processing: ../test_data/videos_to_track/to_track/2021-03-23 MA 34 Plate 4 B004.mp4
# Wating on user to manually select ROI...
# Select a ROI and then press SPACE or ENTER button!
# Cancel the selection process by pressing c button!
# ...ROI selection complete
# original_time_stamp: 0.0
# original_time_stamp: 42.2
# original_time_stamp: 84.4
# original_time_stamp: 126.60000000000002
# original_time_stamp: 168.8
# original_time_stamp: 211.00000000000003
# original_time_stamp: 253.20000000000005
# original_time_stamp: 295.40000000000003
# original_time_stamp: 337.6
# original_time_stamp: 379.8
# original_time_stamp: 422.00000000000006
# original_time_stamp: 464.20000000000005
# original_time_stamp: 506.4000000000001
# original_time_stamp: 548.6000000000001
# original_time_stamp: 590.8000000000001
# original_time_stamp: 633.0
# original_time_stamp: 675.2
# original_time_stamp: 717.4000000000001
# original_time_stamp: 759.6
# original_time_stamp: 801.8000000000001
# original_time_stamp: 844.0000000000001
# original_time_stamp: 886.2
# original_time_stamp: 928.4000000000001
# original_time_stamp: 970.6000000000001
# original_time_stamp: 1012.8000000000002
# original_time_stamp: 1055.0000000000002
# original_time_stamp: 1097.2000000000003
# original_time_stamp: 1139.4
# original_time_stamp: 1181.6000000000001
# original_time_stamp: 1223.8
# original_time_stamp: 1266.0
# original_time_stamp: 1308.2
# original_time_stamp: 1350.4
# original_time_stamp: 1392.6000000000001
# original_time_stamp: 1434.8000000000002
# original_time_stamp: 1477.0
# original_time_stamp: 1519.2
# original_time_stamp: 1561.4
# original_time_stamp: 1603.6000000000001
# original_time_stamp: 1645.8000000000002
# original_time_stamp: 1688.0000000000002
# original_time_stamp: 1730.2000000000003
# original_time_stamp: 1772.4
# original_time_stamp: 1814.6000000000001
# original_time_stamp: 1856.8000000000002
# original_time_stamp: 1899.0000000000002
# original_time_stamp: 1941.2000000000003
# original_time_stamp: 1983.4
# original_time_stamp: 2025.6000000000004
# original_time_stamp: 2067.8
# original_time_stamp: 2110.0000000000005
# original_time_stamp: 2152.2000000000003
# original_time_stamp: 2194.4000000000005
# original_time_stamp: 2236.6000000000004
# original_time_stamp: 2278.8
# original_time_stamp: 2321.0
# original_time_stamp: 2363.2000000000003
# original_time_stamp: 2405.4
# original_time_stamp: 2447.6
# original_time_stamp: 2489.8
# original_time_stamp: 2532.0
# original_time_stamp: 2574.2000000000003
# original_time_stamp: 2616.4
# original_time_stamp: 2658.6000000000004
# original_time_stamp: 2700.8
# original_time_stamp: 2743.0000000000005
# original_time_stamp: 2785.2000000000003
# original_time_stamp: 2827.4000000000005
# original_time_stamp: 2869.6000000000004
# original_time_stamp: 2911.8
# original_time_stamp: 2954.0
# original_time_stamp: 2996.2000000000003
# original_time_stamp: 3038.4
# original_time_stamp: 3080.6000000000004
# original_time_stamp: 3122.8
# original_time_stamp: 3165.0000000000005
# original_time_stamp: 3207.2000000000003
# original_time_stamp: 3249.4
# original_time_stamp: 3291.6000000000004
# original_time_stamp: 3333.8
# original_time_stamp: 3376.0000000000005
# original_time_stamp: 3418.2000000000003
# original_time_stamp: 3460.4000000000005
# original_time_stamp: 3502.6000000000004
# original_time_stamp: 3544.8
# original_time_stamp: 3587.0
# original_time_stamp: 3629.2000000000003
# original_time_stamp: 3671.4
# original_time_stamp: 3713.6000000000004
# original_time_stamp: 3755.8
# original_time_stamp: 3798.0000000000005
# original_time_stamp: 3840.2000000000003
# original_time_stamp: 3882.4000000000005
# original_time_stamp: 3924.6000000000004
# original_time_stamp: 3966.8
# original_time_stamp: 4009.0000000000005
# original_time_stamp: 4051.2000000000007
# original_time_stamp: 4093.4
# original_time_stamp: 4135.6
# original_time_stamp: 4177.8
# original_time_stamp: 4220.000000000001
# original_time_stamp: 4262.2
# original_time_stamp: 4304.400000000001
# original_time_stamp: 4346.6
# original_time_stamp: 4388.800000000001
# original_time_stamp: 4431.0
# original_time_stamp: 4473.200000000001
# original_time_stamp: 4515.400000000001
# original_time_stamp: 4557.6
# original_time_stamp: 4599.8
# original_time_stamp: 4642.0
# original_time_stamp: 4684.200000000001
# original_time_stamp: 4726.400000000001
# original_time_stamp: 4768.6
# original_time_stamp: 4810.8
# original_time_stamp: 4853.000000000001
# original_time_stamp: 4895.2
# original_time_stamp: 4937.400000000001
# original_time_stamp: 4979.6
# original_time_stamp: 5021.800000000001
# original_time_stamp: 5064.0
# original_time_stamp: 5106.200000000001
# original_time_stamp: 5148.400000000001
# original_time_stamp: 5190.6
# original_time_stamp: 5232.8
# original_time_stamp: 5275.0
# original_time_stamp: 5317.200000000001
# original_time_stamp: 5359.400000000001
# original_time_stamp: 5401.6
# original_time_stamp: 5443.8
# original_time_stamp: 5486.000000000001
# original_time_stamp: 5528.200000000001
# original_time_stamp: 5570.400000000001
# original_time_stamp: 5612.6
# original_time_stamp: 5654.800000000001
# original_time_stamp: 5697.0
# original_time_stamp: 5739.200000000001
# original_time_stamp: 5781.400000000001
# original_time_stamp: 5823.6
# original_time_stamp: 5865.8
# original_time_stamp: 5908.0
# original_time_stamp: 5950.200000000001
# original_time_stamp: 5992.400000000001
# original_time_stamp: 6034.6
# original_time_stamp: 6076.8
# original_time_stamp: 6119.000000000001
# original_time_stamp: 6161.200000000001
# original_time_stamp: 6203.400000000001
# original_time_stamp: 6245.6
# original_time_stamp: 6287.800000000001
# original_time_stamp: 6330.000000000001
# original_time_stamp: 6372.200000000001
# original_time_stamp: 6414.400000000001
# original_time_stamp: 6456.6
# original_time_stamp: 6498.8
# original_time_stamp: 6541.0
# original_time_stamp: 6583.200000000001
# original_time_stamp: 6625.400000000001
# original_time_stamp: 6667.6
# original_time_stamp: 6709.8
# original_time_stamp: 6752.000000000001
# original_time_stamp: 6794.200000000001
# original_time_stamp: 6836.400000000001
# original_time_stamp: 6878.6
# original_time_stamp: 6920.800000000001
# original_time_stamp: 6963.000000000001
# original_time_stamp: 7005.200000000001
# original_time_stamp: 7047.400000000001
# original_time_stamp: 7089.6
# original_time_stamp: 7131.800000000001
# original_time_stamp: 7174.0
# original_time_stamp: 7216.200000000001
# original_time_stamp: 7258.400000000001
# original_time_stamp: 7300.6
# original_time_stamp: 7342.8
# original_time_stamp: 7385.000000000001
# original_time_stamp: 7427.200000000001
# original_time_stamp: 7469.400000000001
# original_time_stamp: 7511.6
# original_time_stamp: 7553.800000000001
# original_time_stamp: 7596.000000000001
# original_time_stamp: 7638.200000000001
# original_time_stamp: 7680.400000000001
# original_time_stamp: 7722.6
# original_time_stamp: 7764.800000000001
# original_time_stamp: 7807.0
# original_time_stamp: 7849.200000000001
# original_time_stamp: 7891.400000000001
# original_time_stamp: 7933.6
# original_time_stamp: 7975.8
# original_time_stamp: 8018.000000000001
# original_time_stamp: 8060.2
# original_time_stamp: 8102.4000000000015
# original_time_stamp: 8144.6
# original_time_stamp: 8186.8
# original_time_stamp: 8229.000000000002
# original_time_stamp: 8271.2
# original_time_stamp: 8313.400000000001
# original_time_stamp: 8355.6
# original_time_stamp: 8397.8
# original_time_stamp: 8440.000000000002
# original_time_stamp: 8482.2
# original_time_stamp: 8524.4
# original_time_stamp: 8566.6
# original_time_stamp: 8608.800000000001
# original_time_stamp: 8651.000000000002
# original_time_stamp: 8693.2
# original_time_stamp: 8735.4
# original_time_stamp: 8777.600000000002
# original_time_stamp: 8819.800000000001
# original_time_stamp: 8862.0
# original_time_stamp: 8904.2
# original_time_stamp: 8946.400000000001
# original_time_stamp: 8988.6
# original_time_stamp: 9030.800000000001
# original_time_stamp: 9073.0
# original_time_stamp: 9115.2
# original_time_stamp: 9157.400000000001
# original_time_stamp: 9199.6
# original_time_stamp: 9241.800000000001
# original_time_stamp: 9284.0
# original_time_stamp: 9326.2
# original_time_stamp: 9368.400000000001
# original_time_stamp: 9410.6
# original_time_stamp: 9452.800000000001
# original_time_stamp: 9495.000000000002
# original_time_stamp: 9537.2
# original_time_stamp: 9579.400000000001
# original_time_stamp: 9621.6
# original_time_stamp: 9663.8
# original_time_stamp: 9706.000000000002
# original_time_stamp: 9748.2
# original_time_stamp: 9790.4
# original_time_stamp: 9832.6
# original_time_stamp: 9874.800000000001
# original_time_stamp: 9917.000000000002
# original_time_stamp: 9959.2
# original_time_stamp: 10001.4
# original_time_stamp: 10043.600000000002
# original_time_stamp: 10085.800000000001
# original_time_stamp: 10128.0
# original_time_stamp: 10170.2
# original_time_stamp: 10212.400000000001
# original_time_stamp: 10254.600000000002
# original_time_stamp: 10296.800000000001
# original_time_stamp: 10339.0
# original_time_stamp: 10381.2
# original_time_stamp: 10423.400000000001
# original_time_stamp: 10465.6
# original_time_stamp: 10507.800000000001
# original_time_stamp: 10550.0
# original_time_stamp: 10592.2
# original_time_stamp: 10634.400000000001
# original_time_stamp: 10676.6
# original_time_stamp: 10718.800000000001
# original_time_stamp: 10761.000000000002
# original_time_stamp: 10803.2
# original_time_stamp: 10845.400000000001
# original_time_stamp: 10887.6
# original_time_stamp: 10929.8
# original_time_stamp: 10972.000000000002
# original_time_stamp: 11014.2
# original_time_stamp: 11056.400000000001
# original_time_stamp: 11098.6
# original_time_stamp: 11140.800000000001
# original_time_stamp: 11183.000000000002
# original_time_stamp: 11225.2
# original_time_stamp: 11267.4
# original_time_stamp: 11309.600000000002
# original_time_stamp: 11351.800000000001
# original_time_stamp: 11394.0
# original_time_stamp: 11436.2
# original_time_stamp: 11478.400000000001
# original_time_stamp: 11520.600000000002
# original_time_stamp: 11562.800000000001
# original_time_stamp: 11605.0
# original_time_stamp: 11647.2
# original_time_stamp: 11689.400000000001
# original_time_stamp: 11731.6
# original_time_stamp: 11773.800000000001
# original_time_stamp: 11816.0
# original_time_stamp: 11858.200000000003
# original_time_stamp: 11900.400000000001
# original_time_stamp: 11942.6
# original_time_stamp: 11984.800000000001
# original_time_stamp: 12027.000000000002
# original_time_stamp: 12069.2
# original_time_stamp: 12111.400000000001
# original_time_stamp: 12153.6
# original_time_stamp: 12195.800000000001
# original_time_stamp: 12238.000000000002
# original_time_stamp: 12280.2
# original_time_stamp: 12322.400000000001
# original_time_stamp: 12364.6
# original_time_stamp: 12406.800000000001
# original_time_stamp: 12449.000000000002
# original_time_stamp: 12491.2
# original_time_stamp: 12533.4
# original_time_stamp: 12575.600000000002
# original_time_stamp: 12617.800000000001
# original_time_stamp: 12660.000000000002
# original_time_stamp: 12702.2
# original_time_stamp: 12744.400000000001
# original_time_stamp: 12786.600000000002
# original_time_stamp: 12828.800000000001
# original_time_stamp: 12871.0
# original_time_stamp: 12913.2
# original_time_stamp: 12955.400000000001
# original_time_stamp: 12997.6
# original_time_stamp: 13039.800000000001
# original_time_stamp: 13082.0
# original_time_stamp: 13124.200000000003
# original_time_stamp: 13166.400000000001
# original_time_stamp: 13208.6
# original_time_stamp: 13250.800000000001
# original_time_stamp: 13293.000000000002
# original_time_stamp: 13335.2
# original_time_stamp: 13377.400000000001
# original_time_stamp: 13419.6
# original_time_stamp: 13461.800000000001
# original_time_stamp: 13504.000000000002
# original_time_stamp: 13546.2
# original_time_stamp: 13588.400000000001
# original_time_stamp: 13630.6
# original_time_stamp: 13672.800000000001
# original_time_stamp: 13715.000000000002
# original_time_stamp: 13757.2
# original_time_stamp: 13799.4
# original_time_stamp: 13841.600000000002
# original_time_stamp: 13883.800000000001
# original_time_stamp: 13926.000000000002
# original_time_stamp: 13968.2
# original_time_stamp: 14010.400000000001
# original_time_stamp: 14052.600000000002
# original_time_stamp: 14094.800000000001
# original_time_stamp: 14137.0
# original_time_stamp: 14179.2
# original_time_stamp: 14221.400000000001
# original_time_stamp: 14263.600000000002
# original_time_stamp: 14305.800000000001
# original_time_stamp: 14348.0
# original_time_stamp: 14390.200000000003
# original_time_stamp: 14432.400000000001
# original_time_stamp: 14474.6
# original_time_stamp: 14516.800000000001
# original_time_stamp: 14559.000000000002
# original_time_stamp: 14601.2
# original_time_stamp: 14643.400000000001
# original_time_stamp: 14685.6
# original_time_stamp: 14727.800000000003
# original_time_stamp: 14770.000000000002
# original_time_stamp: 14812.2
# original_time_stamp: 14854.400000000001
# original_time_stamp: 14896.6
# original_time_stamp: 14938.800000000001
# original_time_stamp: 14981.000000000002
# original_time_stamp: 15023.2
# original_time_stamp: 15065.4
# original_time_stamp: 15107.600000000002
# original_time_stamp: 15149.800000000001
# original_time_stamp: 15192.000000000002
# original_time_stamp: 15234.2
# original_time_stamp: 15276.400000000001
# original_time_stamp: 15318.600000000002
# original_time_stamp: 15360.800000000001
# original_time_stamp: 15403.0
# original_time_stamp: 15445.2
# original_time_stamp: 15487.400000000001
# original_time_stamp: 15529.600000000002
# original_time_stamp: 15571.800000000001
# original_time_stamp: 15614.0
# original_time_stamp: 15656.200000000003
# original_time_stamp: 15698.400000000001
# original_time_stamp: 15740.6
# original_time_stamp: 15782.800000000001
# original_time_stamp: 15825.000000000002
# original_time_stamp: 15867.2
# original_time_stamp: 15909.400000000001
# original_time_stamp: 15951.6
# original_time_stamp: 15993.800000000003
# original_time_stamp: 16036.000000000002
# original_time_stamp: 16078.200000000003
# original_time_stamp: 16120.4
# original_time_stamp: 16162.6
# original_time_stamp: 16204.800000000003
# original_time_stamp: 16247.0
# original_time_stamp: 16289.2
# original_time_stamp: 16331.400000000001
# original_time_stamp: 16373.6
# original_time_stamp: 16415.8
# original_time_stamp: 16458.000000000004
# original_time_stamp: 16500.200000000004
# original_time_stamp: 16542.4
# original_time_stamp: 16584.600000000002
# original_time_stamp: 16626.800000000003
# original_time_stamp: 16669.0
# original_time_stamp: 16711.2
# original_time_stamp: 16753.4
# original_time_stamp: 16795.6
# original_time_stamp: 16837.800000000003
# original_time_stamp: 16880.000000000004
# original_time_stamp: 16922.2
# original_time_stamp: 16964.4
# original_time_stamp: 17006.600000000002
# original_time_stamp: 17048.8
# original_time_stamp: 17091.0
# original_time_stamp: 17133.2
# original_time_stamp: 17175.4
# original_time_stamp: 17217.600000000002
# original_time_stamp: 17259.800000000003
# original_time_stamp: 17302.000000000004
# original_time_stamp: 17344.2
# original_time_stamp: 17386.4
# original_time_stamp: 17428.600000000002
# original_time_stamp: 17470.8
# original_time_stamp: 17513.0
# original_time_stamp: 17555.200000000004
# original_time_stamp: 17597.4
# original_time_stamp: 17639.600000000002
# original_time_stamp: 17681.800000000003
# original_time_stamp: 17724.0
# original_time_stamp: 17766.2
# original_time_stamp: 17808.4
# original_time_stamp: 17850.6
# original_time_stamp: 17892.800000000003
# original_time_stamp: 17935.000000000004
# original_time_stamp: 17977.2
# original_time_stamp: 18019.4
# original_time_stamp: 18061.600000000002
# original_time_stamp: 18103.800000000003
# original_time_stamp: 18146.0
# original_time_stamp: 18188.2
# original_time_stamp: 18230.4
# original_time_stamp: 18272.600000000002
# original_time_stamp: 18314.800000000003
# original_time_stamp: 18357.000000000004
# original_time_stamp: 18399.2
# original_time_stamp: 18441.4
# original_time_stamp: 18483.600000000002
# original_time_stamp: 18525.8
# original_time_stamp: 18568.0
# original_time_stamp: 18610.2
# original_time_stamp: 18652.4
# original_time_stamp: 18694.600000000002
# original_time_stamp: 18736.800000000003
# original_time_stamp: 18779.0
# original_time_stamp: 18821.2
# original_time_stamp: 18863.4
# original_time_stamp: 18905.600000000002
# original_time_stamp: 18947.8
# original_time_stamp: 18990.000000000004
# original_time_stamp: 19032.200000000004
# original_time_stamp: 19074.4
# original_time_stamp: 19116.600000000002
# original_time_stamp: 19158.800000000003
# original_time_stamp: 19201.0
# original_time_stamp: 19243.2
# original_time_stamp: 19285.4
# original_time_stamp: 19327.6
# original_time_stamp: 19369.800000000003
# original_time_stamp: 19412.000000000004
# original_time_stamp: 19454.2
# original_time_stamp: 19496.4
# original_time_stamp: 19538.600000000002
# original_time_stamp: 19580.8
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# original_time_stamp: 0.0
# main axis of movement detected along y
# Error. Can't open videos stream for capture. Nothing has been converted.
# ...Template Tracker completed in 18.05s
#
# Actual tracking time for 1 videos: 17.94s (17.94s per video)
